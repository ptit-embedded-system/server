# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in ./venv/lib/python3.9/site-packages (22.3.1)
# Collecting pip
#   Using cached pip-23.1.2-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-23.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install wget numpy IPython opencv-python matplotlib tensorflow pillow Flask
# Out:
# Requirement already satisfied: wget in ./venv/lib/python3.9/site-packages (3.2)
# Requirement already satisfied: numpy in ./venv/lib/python3.9/site-packages (1.23.5)
# Requirement already satisfied: IPython in ./venv/lib/python3.9/site-packages (8.14.0)
# Requirement already satisfied: opencv-python in ./venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: tensorflow in ./venv/lib/python3.9/site-packages (2.12.0)
# Requirement already satisfied: pillow in ./venv/lib/python3.9/site-packages (9.5.0)
# Requirement already satisfied: Flask in ./venv/lib/python3.9/site-packages (2.3.2)
# Requirement already satisfied: backcall in ./venv/lib/python3.9/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: decorator in ./venv/lib/python3.9/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./venv/lib/python3.9/site-packages (from IPython) (0.18.2)
# Requirement already satisfied: matplotlib-inline in ./venv/lib/python3.9/site-packages (from IPython) (0.1.6)
# Requirement already satisfied: pickleshare in ./venv/lib/python3.9/site-packages (from IPython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./venv/lib/python3.9/site-packages (from IPython) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in ./venv/lib/python3.9/site-packages (from IPython) (2.15.1)
# Requirement already satisfied: stack-data in ./venv/lib/python3.9/site-packages (from IPython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in ./venv/lib/python3.9/site-packages (from IPython) (5.9.0)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.9/site-packages (from IPython) (4.6.3)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.9/site-packages (from IPython) (4.8.0)
# Requirement already satisfied: appnope in ./venv/lib/python3.9/site-packages (from IPython) (0.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.9/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./venv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./venv/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./venv/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./venv/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in ./venv/lib/python3.9/site-packages (from tensorflow) (0.4.11)
# Requirement already satisfied: libclang>=13.0.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./venv/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./venv/lib/python3.9/site-packages (from tensorflow) (4.23.2)
# Requirement already satisfied: setuptools in ./venv/lib/python3.9/site-packages (from tensorflow) (65.5.1)
# Requirement already satisfied: six>=1.12.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./venv/lib/python3.9/site-packages (from tensorflow) (1.54.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in ./venv/lib/python3.9/site-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./venv/lib/python3.9/site-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: Werkzeug>=2.3.3 in ./venv/lib/python3.9/site-packages (from Flask) (2.3.4)
# Requirement already satisfied: Jinja2>=3.1.2 in ./venv/lib/python3.9/site-packages (from Flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in ./venv/lib/python3.9/site-packages (from Flask) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in ./venv/lib/python3.9/site-packages (from Flask) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in ./venv/lib/python3.9/site-packages (from Flask) (1.6.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in ./venv/lib/python3.9/site-packages (from Flask) (6.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->Flask) (3.15.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in ./venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in ./venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./venv/lib/python3.9/site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.9/site-packages (from Jinja2>=3.1.2->Flask) (2.1.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.9/site-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython) (0.2.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.19.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in ./venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.9/site-packages (from stack-data->IPython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.9/site-packages (from stack-data->IPython) (2.2.1)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.9/site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in ./venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.5.7)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import wget
import numpy as np
from IPython.display import display
import cv2
from six import BytesIO
import matplotlib.pyplot as plt
import tensorflow as tf

from PIL import Image, ImageDraw, ImageFont



CUSTOM_MODEL_NAME = "my_ssd_mobnet"
PRETRAINED_MODEL_NAME = "ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8"
PRETRAINED_MODEL_URL = "http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz"
TF_RECORD_SCRIPT_NAME = "generate_tfrecord.py"
LABEL_MAP_NAME = "label_map.pbtxt"
TF_PATH = "Tensorflow"


paths = {
    "WORKSPACE_PATH": os.path.join("Tensorflow", "workspace"),
    "SCRIPTS_PATH": os.path.join("Tensorflow", "scripts"),
    "APIMODEL_PATH": os.path.join("Tensorflow", "models"),
    "ANNOTATION_PATH": os.path.join("Tensorflow", "workspace", "annotations"),
    "IMAGE_PATH": os.path.join("Tensorflow", "workspace", "images"),
    "MODEL_PATH": os.path.join("Tensorflow", "workspace", "models"),
    "PRETRAINED_MODEL_PATH": os.path.join("Tensorflow", "workspace", "pre-trained-models"),
    "CHECKPOINT_PATH": os.path.join("Tensorflow", "workspace", "models", CUSTOM_MODEL_NAME),
    "OUTPUT_PATH": os.path.join("Tensorflow", "workspace", "models", CUSTOM_MODEL_NAME, "export"),
    "TFJS_PATH": os.path.join("Tensorflow", "workspace", "models", CUSTOM_MODEL_NAME, "tfjsexport"),
    "TFLITE_PATH": os.path.join("Tensorflow", "workspace", "models", CUSTOM_MODEL_NAME, "tfliteexport"),
    "PROTOC_PATH": os.path.join("Tensorflow", "protoc"),
    "EXPORT_MODEL": os.path.join("Tensorflow", "workspace", "export_model"),
}


files = {
    "PIPELINE_CONFIG": os.path.join("Tensorflow", "workspace", "models", CUSTOM_MODEL_NAME, "pipeline.config"),
    "TF_RECORD_SCRIPT": os.path.join(paths["SCRIPTS_PATH"], TF_RECORD_SCRIPT_NAME),
    "LABELMAP": os.path.join(paths["ANNOTATION_PATH"], LABEL_MAP_NAME),
}
# Out:
# 2023-06-05 01:33:13.262416: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
for path in paths.values():
    if not os.path.exists(path):
        # !mkdir -p {path}

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 85695, done.
# remote: Counting objects: 100% (1294/1294), done.
# remote: Compressing objects: 100% (537/537), done.
# remote: Total 85695 (delta 821), reused 1188 (delta 751), pack-reused 84401
# Receiving objects: 100% (85695/85695), 598.68 MiB | 7.35 MiB/s, done.
# Resolving deltas: 100% (61314/61314), done.
# Updating files: 100% (3487/3487), done.

# %%
# Install Tensorflow object detection and compile these
# !apt-get install protobuf-compiler
# !cd {os.path.join(TF_PATH, 'models', 'research')} && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install .


# Install Tensorflow Object Detection # Do not touch
# url="https://github.com/protocolbuffers/protobuf/releases/download/v22.5/protoc-22.5-win64.zip"
# wget.download(url)
# !move protoc-22.5-win64.zip {paths['PROTOC_PATH']}
# !cd {paths['PROTOC_PATH']} && tar -xf protoc-22.5-win64.zip
# os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
# !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
# !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# zsh:1: command not found: apt-get
# Processing /Users/lap13954/truongnh28/iot/Server/Tensorflow/models/research
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3 (from object-detection==0.1)
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apache-beam (from object-detection==0.1)
#   Downloading apache_beam-2.48.0-cp39-cp39-macosx_10_9_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 4.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from object-detection==0.1) (9.5.0)
# Collecting lxml (from object-detection==0.1)
#   Downloading lxml-4.9.2-cp39-cp39-macosx_10_15_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 6.0 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: matplotlib in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from object-detection==0.1) (3.7.1)
# Collecting Cython (from object-detection==0.1)
#   Downloading Cython-0.29.35-py2.py3-none-any.whl (988 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 988.4/988.4 kB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting contextlib2 (from object-detection==0.1)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting tf-slim (from object-detection==0.1)
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 kB 4.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from object-detection==0.1) (1.16.0)
# Collecting pycocotools (from object-detection==0.1)
#   Downloading pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lvis (from object-detection==0.1)
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from object-detection==0.1) (1.10.1)
# Collecting pandas (from object-detection==0.1)
#   Downloading pandas-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 6.2 MB/s eta 0:00:0000:0100:01
# Collecting tf-models-official>=2.5.1 (from object-detection==0.1)
#   Downloading tf_models_official-2.12.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 5.3 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow_io (from object-detection==0.1)
#   Downloading tensorflow_io-0.32.0-cp39-cp39-macosx_10_14_x86_64.whl (25.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.2/25.2 MB 3.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: keras in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from object-detection==0.1) (2.12.0)
# Collecting pyparsing==2.4.7 (from object-detection==0.1)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 2.1 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0 (from object-detection==0.1)
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 3.2 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting regex (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading regex-2023.6.3-cp39-cp39-macosx_10_9_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 4.9 MB/s eta 0:00:00a 0:00:01
# Collecting tabulate>=0.8.9 (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.23.5)
# Collecting colorama (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting gin-config (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading gin_config-0.5.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: google-api-python-client>=1.6.7 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.88.0)
# Collecting immutabledict (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading immutabledict-2.2.4-py3-none-any.whl (4.1 kB)
# Collecting kaggle>=1.3.9 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading kaggle-1.5.13.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.1 MB/s eta 0:00:00ta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting oauth2client (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.0 MB/s eta 0:00:00
# Collecting opencv-python-headless (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading opencv_python_headless-4.7.0.72-cp37-abi3-macosx_10_16_x86_64.whl (53.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 MB 4.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: psutil>=5.4.3 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.5)
# Collecting py-cpuinfo>=3.3.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting pyyaml<6.0,>=5.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading PyYAML-5.4.1-cp39-cp39-macosx_10_9_x86_64.whl (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 4.5 MB/s eta 0:00:0000:01
# Collecting sentencepiece (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading sentencepiece-0.1.99-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 4.7 MB/s eta 0:00:0000:0100:01
# Collecting seqeval (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow-addons (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_addons-0.20.0-cp39-cp39-macosx_10_14_x86_64.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 2.3 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-datasets (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_datasets-4.9.2-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 6.3 MB/s eta 0:00:0000:0100:01m
# Collecting tensorflow-hub>=0.6.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_hub-0.13.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 3.1 MB/s eta 0:00:00
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_model_optimization-0.7.5-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 4.6 MB/s eta 0:00:0000:01
# Collecting tensorflow-text~=2.12.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_text-2.12.1-cp39-cp39-macosx_10_9_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 4.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tensorflow~=2.12.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Collecting pytz>=2020.1 (from pandas->object-detection==0.1)
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 5.1 MB/s eta 0:00:0000:0100:01
# Collecting tzdata>=2022.1 (from pandas->object-detection==0.1)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 5.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: absl-py>=0.2.2 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Collecting crcmod<2.0,>=1.7 (from apache-beam->object-detection==0.1)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting orjson<4.0 (from apache-beam->object-detection==0.1)
#   Downloading orjson-3.9.0-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.5/240.5 kB 3.4 MB/s eta 0:00:0000:01
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam->object-detection==0.1)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 3.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting cloudpickle~=2.2.1 (from apache-beam->object-detection==0.1)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting fastavro<2,>=0.23.6 (from apache-beam->object-detection==0.1)
#   Downloading fastavro-1.7.4-cp39-cp39-macosx_11_0_x86_64.whl (530 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.8/530.8 kB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting fasteners<1.0,>=0.3 (from apache-beam->object-detection==0.1)
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.54.2)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam->object-detection==0.1)
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Collecting objsize<0.7.0,>=0.6.1 (from apache-beam->object-detection==0.1)
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam->object-detection==0.1)
#   Downloading pymongo-4.3.3-cp39-cp39-macosx_10_9_universal2.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.2/413.2 kB 2.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: protobuf<4.24.0,>=3.20.3 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.23.2)
# Collecting pydot<2,>=1.2.0 (from apache-beam->object-detection==0.1)
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.6.3)
# Collecting zstandard<1,>=0.18.0 (from apache-beam->object-detection==0.1)
#   Downloading zstandard-0.21.0-cp39-cp39-macosx_10_9_x86_64.whl (473 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 5.0 MB/s eta 0:00:0000:0100:01
# Collecting pyarrow<12.0.0,>=3.0.0 (from apache-beam->object-detection==0.1)
#   Downloading pyarrow-11.0.0-cp39-cp39-macosx_10_14_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 6.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cycler>=0.10.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (4.39.4)
# Requirement already satisfied: packaging>=20.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (5.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.19.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=3.1.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->object-detection==0.1) (3.15.0)
# Requirement already satisfied: certifi in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2023.5.7)
# Collecting tqdm (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 2.0 MB/s eta 0:00:00
# Collecting python-slugify (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: urllib3 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.16)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 4.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.11)
# Requirement already satisfied: libclang>=13.0.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (65.5.1)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Collecting dm-tree~=0.1.1 (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading dm_tree-0.1.8-cp39-cp39-macosx_10_9_x86_64.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.4/115.4 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Collecting scikit-learn>=0.21.3 (from seqeval->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading scikit_learn-1.2.2-cp39-cp39-macosx_10_9_x86_64.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 6.6 MB/s eta 0:00:0000:0100:01
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting array-record (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading array_record-0.2.0-py39-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 6.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.3)
# Collecting etils[enp,epath]>=0.9.0 (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading etils-1.3.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 4.8 MB/s eta 0:00:00
# Collecting promise (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow-metadata (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_metadata-1.13.1-py3-none-any.whl (28 kB)
# Collecting toml (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.38.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (6.6.0)
# Collecting joblib>=1.1.1 (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1)
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1)
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.4)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/lap13954/truongnh28/iot/Server/venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, pycocotools, crcmod, dill, kaggle, seqeval, promise
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1655312 sha256=253bfdf8886c628791065520ff94cdc975a14ba7e39b66acf304d0c195eb2457
#   Stored in directory: /private/var/folders/x5/z2myt6f12b38hsycgtz9c0hc0000gn/T/pip-ephem-wheel-cache-cgyftz7l/wheels/94/a1/31/41370b3d4826c4f014dd39c8b3d3c345e6b750f24c9c415791
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=43993 sha256=c5aff93aeff6e2edc71c0bf5679cafa929fb0b4d50aa7747189cd4d0d5ca46ce
#   Stored in directory: /Users/lap13954/Library/Caches/pip/wheels/5a/29/4d/510c0e098c49c5e49519f430481a5425e60b8752682d7b1e55
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp39-cp39-macosx_10_9_universal2.whl size=155273 sha256=e0cf9420572a4eeee64fd7816af262152c9182e5f6513673c8fed66f1cc2b5e0
#   Stored in directory: /Users/lap13954/Library/Caches/pip/wheels/2f/58/25/e78f1f766e904a9071266661d20d0bc6644df86bcd160aba11
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-py3-none-any.whl size=18832 sha256=c53271e7dd3a41b2727b27c063d5478f7a7189bdbc7d23a1ed28ee49adc657f6
#   Stored in directory: /Users/lap13954/Library/Caches/pip/wheels/4a/6c/a6/ffdd136310039bf226f2707a9a8e6857be7d70a3fc061f6b36
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78542 sha256=de352e3c971ea0a527832aa51c5409b3a53b02965402ffc3d2f947cef9a6f186
#   Stored in directory: /Users/lap13954/Library/Caches/pip/wheels/4f/0b/ce/75d96dd714b15e51cb66db631183ea3844e0c4a6d19741a149
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.13-py3-none-any.whl size=77716 sha256=c79eead525365673fa78e3d7583339a4dd80871db11bd536dd56ff15893010f9
#   Stored in directory: /Users/lap13954/Library/Caches/pip/wheels/9c/45/15/6d6d116cd2539fb8f450d64b0aee4a480e5366bb11b42ac763
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16164 sha256=34b55a3ebdccfc5a9a0f3963673110187e54d7e162bd3e46544052e50ef4cf36
#   Stored in directory: /Users/lap13954/Library/Caches/pip/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21486 sha256=d4b9432c1b540512df2cb72567c09273a2a53fc5124020982752cba205a0bd8f
#   Stored in directory: /Users/lap13954/Library/Caches/pip/wheels/e1/e8/83/ddea66100678d139b14bc87692ece57c6a2a937956d2532608
# Successfully built object-detection avro-python3 pycocotools crcmod dill kaggle seqeval promise
# Installing collected packages: text-unidecode, sentencepiece, pytz, py-cpuinfo, gin-config, docopt, dm-tree, crcmod, zstandard, tzdata, typeguard, tqdm, toml, threadpoolctl, tf-slim, tensorflow-model-optimization, tensorflow_io, tensorflow-hub, tabulate, regex, pyyaml, python-slugify, pyparsing, pyarrow, promise, portalocker, orjson, opencv-python-headless, objsize, lxml, joblib, immutabledict, fasteners, fastavro, etils, dnspython, dill, Cython, contextlib2, colorama, cloudpickle, avro-python3, tensorflow-metadata, tensorflow-addons, scikit-learn, sacrebleu, pymongo, pydot, pandas, kaggle, hdfs, seqeval, pycocotools, oauth2client, lvis, apache-beam, array-record, tensorflow-datasets, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
# Successfully installed Cython-0.29.35 apache-beam-2.48.0 array-record-0.2.0 avro-python3-1.10.2 cloudpickle-2.2.1 colorama-0.4.6 contextlib2-21.6.0 crcmod-1.7 dill-0.3.1.1 dm-tree-0.1.8 dnspython-2.3.0 docopt-0.6.2 etils-1.3.0 fastavro-1.7.4 fasteners-0.18 gin-config-0.5.0 hdfs-2.7.0 immutabledict-2.2.4 joblib-1.2.0 kaggle-1.5.13 lvis-0.5.3 lxml-4.9.2 oauth2client-4.1.3 object-detection-0.1 objsize-0.6.1 opencv-python-headless-4.7.0.72 orjson-3.9.0 pandas-2.0.2 portalocker-2.7.0 promise-2.3 py-cpuinfo-9.0.0 pyarrow-11.0.0 pycocotools-2.0.6 pydot-1.4.2 pymongo-4.3.3 pyparsing-2.4.7 python-slugify-8.0.1 pytz-2023.3 pyyaml-5.4.1 regex-2023.6.3 sacrebleu-2.2.0 scikit-learn-1.2.2 sentencepiece-0.1.99 seqeval-1.2.2 tabulate-0.9.0 tensorflow-addons-0.20.0 tensorflow-datasets-4.9.2 tensorflow-hub-0.13.0 tensorflow-metadata-1.13.1 tensorflow-model-optimization-0.7.5 tensorflow-text-2.12.1 tensorflow_io-0.32.0 text-unidecode-1.3 tf-models-official-2.12.0 tf-slim-1.1.0 threadpoolctl-3.1.0 toml-0.10.2 tqdm-4.65.0 typeguard-2.13.3 tzdata-2023.3 zstandard-0.21.0
